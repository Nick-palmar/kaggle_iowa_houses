# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# get the train and test csv
X = pd.read_csv('../input/home-data-for-ml-course/train.csv', index_col='Id')
X_test = pd.read_csv('../input/home-data-for-ml-course/test.csv', index_col='Id')

y = X.pop('SalePrice')

X.head()

# %%
from sklearn.model_selection import train_test_split
# Break off validation set from training data for xgb
X_train_full, X_valid_full, y_train, y_valid = train_test_split(X, y, train_size=0.8, test_size=0.2,
                                                                random_state=0)

# %%
X.info()

# %%
# get all the sales prices
y

# %%
# find low cardinality categorical columns
low_card_cols = [col for col in X.columns if X[col].nunique() < 15 and X[col].dtype == 'object']
low_card_cols = set(low_card_cols)
low_card_cols

# %%
# get the numerical columns
numerical_cols = set([col for col in X.columns if X[col].dtype in ['int64', 'float64']])
numerical_cols

# %%
# look at the numerical cols with garage
garage_cols = [col for col in X.columns if col.startswith('Garage')]
X[garage_cols].describe()

# %%
# Look at garage area
zero_area = X[X['GarageArea'] == 0]
zero_area[garage_cols].head(10)

# get the nuercial garage columns
numerical_garage = ['GarageYrBlt', 'GarageCars', 'GarageArea']

# consider: type, finishm cond, qual -> all caterogrical, many NaN

# %%
# get the object garabe cols and add them to many nulls (below)
obj_garage_cols = set(garage_cols) - set(numerical_garage)
print(obj_garage_cols)

# %%
# remove the year the garage was built in. The other garage info wil be enough and there are plenty of null values here
numerical_cols = list(numerical_cols - {'GarageYrBlt'})
numerical_cols

# %%
# find null columns
nulls = X.isna().sum()[X.isna().sum() > 0]
many_nulls_list = nulls[nulls > 100]
print(many_nulls_list)

"""
LotFrontage: Linear feet of street connected to property
most likely data not avaliable

Alley: Type of alley access to property
Makes sense to input as a constant value of none

FireplaceQu: Fireplace quality
Many NA fireplaces -> null

PoolQC: Pool quality
Many NA pools -> null

Fence: Fence Quality
Many NA fences- > null

MiscFeature: Miscellaneous feature not covered in other categories
Many NA (none) other features -> null

"""

# %%
# get the set of values in columns with many unique values (the imputers and data transformers on these columns may impact results)
many_null_cols = [col for col in many_nulls_list.index]
many_null_col_vals = [set(X[col].dropna()) for col in many_null_cols]
many_nulls = dict(zip(many_null_cols, many_null_col_vals))
many_nulls

# %%
# remove the basement null cols
replace_null_cols = [col for col in low_card_cols if X[col].isna().sum() > 10]
replace_null_cols

# %%
# add the columns with many nulls to the garage categorical cols to get the final columns with many nulls to replace
# replace_null_cols = many_null_cols[1:] + list(obj_garage_cols)
# replace_null_cols

# %%
# check categorical transformer for many null cols and drop
low_card_cols = list(low_card_cols - set(replace_null_cols))
low_card_cols

# %%
X[low_card_cols].isna().sum()
# removed all columns that come in empty from categorical cols (all in null cols now)

# %%
# explore the columns that start with lot to see if lot frontage can be removed
lots = [col for col in X.columns if col.startswith('Lot')]
lot_df = X[lots].sort_values(by='LotFrontage', ascending=False)
lot_df.head(20)

# %%
# plot lot frontage vs lot area
import seaborn as sns
ax = sns.regplot(x=lot_df['LotFrontage'], y=lot_df['LotArea'])
ax.set_title('Lot frontage vs area')

# %%
# calculate pearson correlation
pearsoncorr = lot_df.corr(method='pearson')
pearsoncorr

# consider dropping lot frontage since there is moderate correlation with lot area

# %%
# change the feature data to only include the columns for low cardinality categorical columns and numbers
X_clean = X[numerical_cols + low_card_cols + replace_null_cols].copy()
X_test_clean = X_test[numerical_cols + low_card_cols + replace_null_cols].copy()
X_train_unfit = X_train_full[numerical_cols + low_card_cols + replace_null_cols].copy()
X_valid_unfit = X_valid_full[numerical_cols + low_card_cols + replace_null_cols].copy()
X_clean.head()

# %%
print(X_valid_unfit.shape, X_train_unfit.shape)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, StandardScaler, RobustScaler
from sklearn.metrics import mean_absolute_error

# deal with numerical cols
numerical_transformer = Pipeline(steps = [
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', RobustScaler())
])

# deal with columns that have many null values
many_null_transformer = Pipeline(steps = [
    ('imputer', SimpleImputer(strategy='constant')),
    ('onehot', OneHotEncoder(handle_unknown='ignore', sparse=False))
])

# deal with categorical columns. Test two strategies for the imputer
categorical_transformer_1 = Pipeline(steps = [
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore', sparse=False))
])

preprocessor_1 = ColumnTransformer(
    transformers = [
        ('num', numerical_transformer, numerical_cols),
        ('categorical', categorical_transformer_1, low_card_cols+replace_null_cols)
    ])

# ('many_null', many_null_transformer, replace_null_cols)

# %%
from sklearn.model_selection import cross_val_score
from typing import Union
from sklearn.ensemble import RandomForestRegressor
import xgboost as xgb
from sklearn.metrics import mean_absolute_error

def test_model(model: Union[RandomForestRegressor, xgb.XGBRegressor], preprocesser: ColumnTransformer) -> float:
  
    # check if xg boost is being used
    if type(model) != RandomForestRegressor:
        # fit the eval set before passing it to fit params
        X_val_eval = X_valid_unfit.copy()
        # add only preprocessor to the pipeline to process the X_val_eval
        eval_pipeline = Pipeline(steps = [('preprocess', preprocesser)])
        # fit the eval set to this new pipeline
        X_train = eval_pipeline.fit_transform(X_train_unfit)
        X_val_eval = eval_pipeline.transform(X_val_eval)
        
#         print(X_val_eval)

        fit_params = {'early_stopping_rounds': 20,
            'eval_metric': 'mae',
            'verbose': True,
            'eval_set': [(X_val_eval, y_valid)]}
        
        # use cross validation on 80:20 splits to check model accuracy using all data
        scores = -1 * cross_val_score(model, X_train, y_train, cv=5, scoring='neg_mean_absolute_error', fit_params=fit_params)
        
#         # fit the model 
#         model.fit(X_train, y_train, early_stopping_rounds=8, eval_set = [(X_val_eval, y_valid)])
        
#         # make predictions on the validation data
#         predictions = model.predict(X_val_eval)
        
#         # score the model using mae
#         scores = mean_absolute_error(predictions, y_valid)
        
    else:
        # create the pipeline for the model
        model_pipeline = Pipeline(steps = [
            ('preprocess', preprocesser),
            ('model', model)
        ])
    
        # use cross validation on 80:20 splits to check model accuracy using all data
        scores = -1 * cross_val_score(model_pipeline, X_clean, y, cv=5, scoring='neg_mean_absolute_error')
    
    return scores.mean()

# %%
# create a few random forest models
# model_1 = RandomForestRegressor(n_estimators=100, random_state=0)
# model_2 = RandomForestRegressor(n_estimators=200, random_state=0)
# model_3 = RandomForestRegressor(n_estimators=300, random_state=0)
# model_4 = RandomForestRegressor(n_estimators=400, random_state=0)
# model_5 = RandomForestRegressor(n_estimators=325, random_state=0)

# rf_list = [model_1, model_2, model_3, model_4, model_5]
# accuracy_1 = []
# for model in rf_list:
#     accuracy_1.append(test_model(model, preprocessor_1))

"""
Results
17582.88258904109
17545.992270547944
17532.8472283105
17562.180580479453
17559.728131506847

Run 2
17696.57582191781
17629.291688356163
17618.58353652968
17606.96818150685
17606.63126027397
"""

# %%
# num_estimators = [100, 200, 300, 400, 325]
# if accuracy_1 == None:
#     accuracy_1 = [17668.580184931507, 17595.95196232877, 17533.18764611872, 17550.457345890412, 17548.591466807167]
# # graph the estimators v accuracy
# sns.set_style('darkgrid')
# ax = sns.lineplot(x=num_estimators, y=accuracy_1)
# ax.set_title('Model Accuracy vs Num Trees')
# ax.set_xlabel('Num Trees')
# ax.set_ylabel('House Price Prediction Error ($)')

# %%
# model_6 = RandomForestRegressor(n_estimators=300, max_depth=25, random_state=0)
# model_7 = RandomForestRegressor(n_estimators=300, max_depth=40, random_state=0)
# model_8 = RandomForestRegressor(n_estimators=300, max_depth=60, random_state=0)


# accuracy_2 = []
# rf_list_2 = [model_6, model_7, model_8]
# for model in rf_list_2:
#     accuracy_2.append(test_model(model, preprocessor_1))
"""
Results
17552.264642781876
17545.47420156556
17573.30147162427
"""

# %%
# depth_cols = [25, 40, 60]
# ax_2 = sns.lineplot(x=depth_cols, y=accuracy_2)
# ax_2.set_title('Model Accuracy vs Tree Depth')
# ax_2.set_xlabel('Tree Depth')
# ax_2.set_ylabel('House Price Prediction Error ($)')

# %%
# model_9 = RandomForestRegressor(n_estimators=300, max_depth=40, max_features=10, random_state=0)
# model_10 = RandomForestRegressor(n_estimators=300, max_depth=40, max_features=20, random_state=0)
# model_11 = RandomForestRegressor(n_estimators=300, max_depth=40, max_features=35, random_state=0)
# model_12 = RandomForestRegressor(n_estimators=300, max_depth=40, max_features=50, random_state=0)


# accuracy_3 = []
# rf_list_3 = [model_9, model_10, model_11, model_12]
# for model in rf_list_3:
#     accuracy_3.append(test_model(model, preprocessor_1))

# %%
# model_13 = RandomForestRegressor(n_estimators=300, max_depth=40, max_features = 25, random_state=0)
# accuracy_3.append(test_model(model_13, preprocessor_1))

# %%
# model_13_2 = RandomForestRegressor(n_estimators=300, max_depth=40, max_features = 30, random_state=0)
# accuracy_3.append(test_model(model_13_2, preprocessor_1))

# %%
# max_feature_vals = [10, 20, 35, 50, 25, 30]
# ax_3 = sns.lineplot(x=max_feature_vals, y=accuracy_3)
# ax_3.set_title('Model Accuracy vs Max Features')
# ax_3.set_xlabel('Max Features')
# ax_3.set_ylabel('House Price Prediction Error ($)')

# %%
# model_14 = RandomForestRegressor(n_estimators=300, max_depth=40, max_features=30, min_samples_leaf=2, random_state=0)
# model_15 = RandomForestRegressor(n_estimators=300, max_depth=40, max_features=30, min_samples_leaf=5, random_state=0)
# model_16 = RandomForestRegressor(n_estimators=300, max_depth=40, max_features=30, min_samples_leaf=10, random_state=0)
# model_17 = RandomForestRegressor(n_estimators=300, max_depth=40, max_features=30, min_samples_leaf=20, random_state=0)


# accuracy_4 = []
# rf_list_4 = [model_14, model_15, model_16, model_17]
# for model in rf_list_4:
#     accuracy_4.append(test_model(model, preprocessor_1))

# %%
# min_sample_leaf_vals = [2, 5, 10, 20]
# ax_4 = sns.lineplot(x=min_sample_leaf_vals, y=accuracy_4)
# ax_4.set_title('Model Accuracy vs Min Sample Leaves')
# ax_4.set_xlabel('Min Sample Leaves')
# ax_4.set_ylabel('House Price Prediction Error ($)')

# %%
# model_18 = RandomForestRegressor(n_estimators=300, max_depth=40, min_samples_split=3, max_features=30, random_state=0)
# model_19 = RandomForestRegressor(n_estimators=300, max_depth=40, min_samples_split=5, max_features=30, random_state=0)
# model_20 = RandomForestRegressor(n_estimators=300, max_depth=40, min_samples_split=10, max_features=30, random_state=0)
# model_21 = RandomForestRegressor(n_estimators=300, max_depth=40, min_samples_split=20, max_features=30, random_state=0)


# accuracy_5 = []
# rf_list_5 = [model_18, model_19, model_20, model_21]
# for model in rf_list_5:
#     accuracy_5.append(test_model(model, preprocessor_1))

# %%
# min_samples_split_vals = [3, 5, 10, 20]
# ax_5 = sns.lineplot(x=min_samples_split_vals, y=accuracy_5)
# ax_5.set_title('Model Accuracy vs Min Sample Split')
# ax_5.set_xlabel('Min Sample Split')
# ax_5.set_ylabel('House Price Prediction Error ($)')

# %%
# try out the optimal rf, keep max_features at 25 to avoid over fitting
# rf_model = RandomForestRegressor(n_estimators=300, max_depth=40, max_features=25, random_state=0)
# # create the pipeline for the final model
# rf_pipeline = Pipeline(steps = [
#     ('preprocess', preprocessor_1),
#     ('model', rf_model)
# ])
# rf_pipeline.fit(X_clean, y)

# # make predictions with test data and score the model
# rf_preds_test = rf_pipeline.predict(X_test_clean)

# %%
# submit the rf model
# output = pd.DataFrame({'Id': X_test_clean.index,
#                        'SalePrice': rf_preds_test})
# output.to_csv('rf_submission.csv', index=False)

# %%
# use early stopping rounds with verbose to find a good number of n_estimators for early stopping round
# print(test_model(xgb.XGBRegressor(random_state=0, n_estimators=1000), preprocessor_1))
# ans -> 18493.424433342276

# %%
# use early stopping rounds with verbose to find a good number of n_estimators for early stopping round
# print(test_model(xgb.XGBRegressor(random_state=0, n_estimators=1000, learning_rate=0.05), preprocessor_1))
# ans ->16457.97133396267

# %%
# use early stopping rounds with verbose to find a good number of n_estimators for early stopping round
# print(test_model(xgb.XGBRegressor(random_state=0, n_estimators=1000, learning_rate=0.01), preprocessor_1))
# ans -> 16555.01474050899

# %%
# use early stopping rounds with verbose to find a good number of n_estimators for early stopping round
# print(test_model(xgb.XGBRegressor(random_state=0, n_estimators=1000, learning_rate=0.2), preprocessor_1))
# ans -> 17707.34432746185

# %%
# use early stopping rounds with verbose to find a good number of n_estimators for early stopping round
# print(test_model(xgb.XGBRegressor(random_state=0, n_estimators=1000, learning_rate=0.008), preprocessor_1))
# ans -> 16497.30312636126

# %%
# use early stopping rounds with verbose to find a good number of n_estimators for early stopping round
# print(test_model(xgb.XGBRegressor(random_state=0, n_estimators=1000, learning_rate=0.008), preprocessor_1))
# ans -> 16377.387845803645

# %%
# use early stopping rounds with verbose to find a good number of n_estimators for early stopping round
print(test_model(xgb.XGBRegressor(random_state=0, n_estimators=1500, learning_rate=0.008), preprocessor_1))
# ans -> 16362.271127724245
# Out:
# [0]	validation_0-mae:179941.56250
# [1]	validation_0-mae:178525.21875
# [2]	validation_0-mae:177119.96875
# [3]	validation_0-mae:175727.85938
# [4]	validation_0-mae:174360.12500
# [5]	validation_0-mae:173002.28125
# [6]	validation_0-mae:171650.26562
# [7]	validation_0-mae:170314.28125
# [8]	validation_0-mae:168978.54688
# [9]	validation_0-mae:167659.20312
# [10]	validation_0-mae:166351.82812
# [11]	validation_0-mae:165047.50000
# [12]	validation_0-mae:163756.23438
# [13]	validation_0-mae:162473.46875
# [14]	validation_0-mae:161203.71875
# [15]	validation_0-mae:159950.59375
# [16]	validation_0-mae:158693.71875
# [17]	validation_0-mae:157465.00000
# [18]	validation_0-mae:156232.71875
# [19]	validation_0-mae:155030.00000
# [20]	validation_0-mae:153825.25000
# [21]	validation_0-mae:152631.79688
# [22]	validation_0-mae:151461.87500
# [23]	validation_0-mae:150273.95312
# [24]	validation_0-mae:149119.28125
# [25]	validation_0-mae:147952.15625
# [26]	validation_0-mae:146805.60938
# [27]	validation_0-mae:145668.35938
# [28]	validation_0-mae:144526.17188
# [29]	validation_0-mae:143387.53125
# [30]	validation_0-mae:142291.43750
# [31]	validation_0-mae:141179.84375
# [32]	validation_0-mae:140072.67188
# [33]	validation_0-mae:138983.31250
# [34]	validation_0-mae:137900.96875
# [35]	validation_0-mae:136827.20312
# [36]	validation_0-mae:135756.76562
# [37]	validation_0-mae:134697.51562
# [38]	validation_0-mae:133632.65625
# [39]	validation_0-mae:132586.17188
# [40]	validation_0-mae:131550.57812
# [41]	validation_0-mae:130515.25000
# [42]	validation_0-mae:129502.25000
# [43]	validation_0-mae:128487.01562
# [44]	validation_0-mae:127490.00000
# [45]	validation_0-mae:126483.38281
# [46]	validation_0-mae:125500.17969
# [47]	validation_0-mae:124541.01562
# [48]	validation_0-mae:123567.94531
# [49]	validation_0-mae:122612.35938
# [50]	validation_0-mae:121646.74219
# [51]	validation_0-mae:120696.72656
# [52]	validation_0-mae:119754.03906
# [53]	validation_0-mae:118818.47656
# [54]	validation_0-mae:117900.35938
# [216]	validation_0-mae:35903.39844
# [217]	validation_0-mae:35680.25000
# [218]	validation_0-mae:35459.56250
# [219]	validation_0-mae:35241.64062
# [220]	validation_0-mae:35020.84766
# [221]	validation_0-mae:34809.94141
# [222]	validation_0-mae:34598.98828
# [223]	validation_0-mae:34393.19531
# [224]	validation_0-mae:34183.86328
# [225]	validation_0-mae:33987.20703
# [226]	validation_0-mae:33788.40625
# [227]	validation_0-mae:33581.49219
# [228]	validation_0-mae:33391.65625
# [229]	validation_0-mae:33194.60938
# [230]	validation_0-mae:33008.20312
# [231]	validation_0-mae:32810.56250
# [232]	validation_0-mae:32618.24023
# [233]	validation_0-mae:32426.15039
# [234]	validation_0-mae:32237.96289
# [235]	validation_0-mae:32045.89648
# [236]	validation_0-mae:31856.14062
# [237]	validation_0-mae:31667.38086
# [238]	validation_0-mae:31484.68555
# [239]	validation_0-mae:31302.95898
# [240]	validation_0-mae:31119.53125
# [241]	validation_0-mae:30938.17383
# [242]	validation_0-mae:30764.28711
# [243]	validation_0-mae:30588.39062
# [244]	validation_0-mae:30414.52148
# [245]	validation_0-mae:30236.50000
# [246]	validation_0-mae:30062.75977
# [247]	validation_0-mae:29894.60938
# [248]	validation_0-mae:29729.55469
# [249]	validation_0-mae:29568.60352
# [250]	validation_0-mae:29411.75977
# [251]	validation_0-mae:29248.83594
# [252]	validation_0-mae:29094.06250
# [253]	validation_0-mae:28940.66406
# [254]	validation_0-mae:28783.81836
# [255]	validation_0-mae:28634.07031
# [256]	validation_0-mae:28484.72266
# [257]	validation_0-mae:28336.04883
# [258]	validation_0-mae:28184.84180
# [259]	validation_0-mae:28028.94922
# [260]	validation_0-mae:27877.37305
# [261]	validation_0-mae:27723.68555
# [262]	validation_0-mae:27574.99805
# [263]	validation_0-mae:27431.46094
# [264]	validation_0-mae:27293.26172
# [265]	validation_0-mae:27155.77539
# [266]	validation_0-mae:27019.45703
# [267]	validation_0-mae:26890.79297
# [268]	validation_0-mae:26759.50391
# [269]	validation_0-mae:26628.80273
# [270]	validation_0-mae:26501.47852
# [271]	validation_0-mae:26375.39453
# [272]	validation_0-mae:26252.46289
# [273]	validation_0-mae:26132.87305
# [274]	validation_0-mae:26013.12891
# [275]	validation_0-mae:25897.67383
# [276]	validation_0-mae:25779.14453
# [277]	validation_0-mae:25663.70898
# [278]	validation_0-mae:25549.62500
# [279]	validation_0-mae:25436.53320
# [280]	validation_0-mae:25326.57812
# [281]	validation_0-mae:25216.18555
# [282]	validation_0-mae:25105.08203
# [283]	validation_0-mae:24998.41016
# [284]	validation_0-mae:24891.38672
# [285]	validation_0-mae:24784.42773
# [286]	validation_0-mae:24670.32227
# [287]	validation_0-mae:24556.32422
# [288]	validation_0-mae:24448.72266
# [289]	validation_0-mae:24337.15430
# [290]	validation_0-mae:24229.90625
# [291]	validation_0-mae:24131.41016
# [292]	validation_0-mae:24034.53125
# [293]	validation_0-mae:23930.64648
# [294]	validation_0-mae:23835.27930
# [295]	validation_0-mae:23734.61328
# [296]	validation_0-mae:23635.14258
# [378]	validation_0-mae:19019.03711
# [379]	validation_0-mae:18994.08984
# [380]	validation_0-mae:18966.18945
# [381]	validation_0-mae:18941.72656
# [382]	validation_0-mae:18913.87500
# [383]	validation_0-mae:18888.31250
# [384]	validation_0-mae:18864.64062
# [385]	validation_0-mae:18832.65039
# [386]	validation_0-mae:18806.31250
# [387]	validation_0-mae:18783.40625
# [388]	validation_0-mae:18753.31836
# [389]	validation_0-mae:18727.24219
# [390]	validation_0-mae:18699.15625
# [391]	validation_0-mae:18671.22852
# [392]	validation_0-mae:18652.14844
# [393]	validation_0-mae:18627.37500
# [394]	validation_0-mae:18600.38672
# [395]	validation_0-mae:18576.76562
# [396]	validation_0-mae:18553.68750
# [397]	validation_0-mae:18527.71875
# [398]	validation_0-mae:18507.14648
# [399]	validation_0-mae:18485.26758
# [400]	validation_0-mae:18459.88867
# [401]	validation_0-mae:18440.73633
# [402]	validation_0-mae:18418.63281
# [403]	validation_0-mae:18394.59570
# [404]	validation_0-mae:18376.36328
# [405]	validation_0-mae:18353.55859
# [406]	validation_0-mae:18330.68945
# [407]	validation_0-mae:18311.29492
# [408]	validation_0-mae:18289.43750
# [409]	validation_0-mae:18270.72852
# [410]	validation_0-mae:18251.21484
# [411]	validation_0-mae:18229.60547
# [412]	validation_0-mae:18210.29492
# [413]	validation_0-mae:18192.70117
# [414]	validation_0-mae:18172.45508
# [415]	validation_0-mae:18154.52930
# [416]	validation_0-mae:18134.10352
# [417]	validation_0-mae:18115.13672
# [418]	validation_0-mae:18099.82812
# [419]	validation_0-mae:18080.23242
# [420]	validation_0-mae:18064.37695
# [421]	validation_0-mae:18046.60156
# [422]	validation_0-mae:18032.33008
# [423]	validation_0-mae:18019.71484
# [424]	validation_0-mae:18005.63672
# [425]	validation_0-mae:17993.54492
# [426]	validation_0-mae:17974.96680
# [427]	validation_0-mae:17961.35547
# [428]	validation_0-mae:17942.56836
# [429]	validation_0-mae:17924.29297
# [430]	validation_0-mae:17911.32812
# [431]	validation_0-mae:17894.25000
# [432]	validation_0-mae:17881.22656
# [433]	validation_0-mae:17863.77148
# [434]	validation_0-mae:17847.65625
# [435]	validation_0-mae:17836.43750
# [436]	validation_0-mae:17819.81641
# [437]	validation_0-mae:17806.97852
# [438]	validation_0-mae:17794.77734
# [439]	validation_0-mae:17784.45703
# [440]	validation_0-mae:17774.03125
# [441]	validation_0-mae:17764.41602
# [442]	validation_0-mae:17754.51562
# [443]	validation_0-mae:17745.10352
# [444]	validation_0-mae:17733.55078
# [445]	validation_0-mae:17724.06836
# [446]	validation_0-mae:17712.66992
# [447]	validation_0-mae:17701.83008
# [448]	validation_0-mae:17690.83203
# [449]	validation_0-mae:17680.92383
# [450]	validation_0-mae:17669.23047
# [451]	validation_0-mae:17660.96875
# [452]	validation_0-mae:17645.98438
# [453]	validation_0-mae:17637.82617
# [454]	validation_0-mae:17629.68750
# [455]	validation_0-mae:17616.68164
# [456]	validation_0-mae:17601.53516
# [457]	validation_0-mae:17594.00781
# [458]	validation_0-mae:17584.09766
# [459]	validation_0-mae:17574.35156
# [460]	validation_0-mae:17562.25781
# [461]	validation_0-mae:17555.15820
# [462]	validation_0-mae:17544.64258
# [463]	validation_0-mae:17534.41016
# [464]	validation_0-mae:17527.13477
# [465]	validation_0-mae:17515.47852
# [466]	validation_0-mae:17504.78516
# [467]	validation_0-mae:17494.00586
# [468]	validation_0-mae:17488.41992
# [469]	validation_0-mae:17478.80859
# [470]	validation_0-mae:17473.23047
# [471]	validation_0-mae:17464.22266
# [472]	validation_0-mae:17458.87500
# [473]	validation_0-mae:17450.48047
# [474]	validation_0-mae:17446.08789
# [475]	validation_0-mae:17439.00586
# [476]	validation_0-mae:17435.24219
# [477]	validation_0-mae:17429.87305
# [478]	validation_0-mae:17423.51367
# [479]	validation_0-mae:17417.77930
# [480]	validation_0-mae:17414.28320
# [481]	validation_0-mae:17408.88281
# [482]	validation_0-mae:17401.85547
# [483]	validation_0-mae:17396.49023
# [484]	validation_0-mae:17390.96484
# [485]	validation_0-mae:17384.91797
# [486]	validation_0-mae:17377.56445
# [487]	validation_0-mae:17372.65430
# [488]	validation_0-mae:17367.27148
# [489]	validation_0-mae:17362.25977
# [490]	validation_0-mae:17356.62305
# [491]	validation_0-mae:17350.25977
# [492]	validation_0-mae:17343.77734
# [493]	validation_0-mae:17336.70508
# [494]	validation_0-mae:17331.61719
# [495]	validation_0-mae:17324.42383
# [496]	validation_0-mae:17318.32227
# [497]	validation_0-mae:17312.21875
# [498]	validation_0-mae:17307.83398
# [499]	validation_0-mae:17302.50781
# [500]	validation_0-mae:17297.03125
# [501]	validation_0-mae:17289.43359
# [502]	validation_0-mae:17283.50977
# [503]	validation_0-mae:17277.72852
# [504]	validation_0-mae:17272.60352
# [505]	validation_0-mae:17266.98047
# [506]	validation_0-mae:17263.45312
# [507]	validation_0-mae:17255.00781
# [508]	validation_0-mae:17250.21875
# [509]	validation_0-mae:17245.15039
# [510]	validation_0-mae:17240.05078
# [511]	validation_0-mae:17235.13086
# [512]	validation_0-mae:17231.16797
# [513]	validation_0-mae:17223.15625
# [514]	validation_0-mae:17220.12891
# [515]	validation_0-mae:17217.33594
# [516]	validation_0-mae:17212.71289
# [517]	validation_0-mae:17208.88281
# [518]	validation_0-mae:17202.39258
# [519]	validation_0-mae:17198.17383
# [520]	validation_0-mae:17195.56836
# [521]	validation_0-mae:17188.43750
# [522]	validation_0-mae:17186.56055
# [523]	validation_0-mae:17182.51953
# [524]	validation_0-mae:17180.60938
# [525]	validation_0-mae:17177.81445
# [526]	validation_0-mae:17177.36719
# [527]	validation_0-mae:17173.45117
# [528]	validation_0-mae:17167.16211
# [529]	validation_0-mae:17166.02539
# [530]	validation_0-mae:17160.01367
# [531]	validation_0-mae:17158.14453
# [532]	validation_0-mae:17155.86523
# [533]	validation_0-mae:17153.74609
# [534]	validation_0-mae:17149.52539
# [535]	validation_0-mae:17148.63281
# [536]	validation_0-mae:17143.23633
# [537]	validation_0-mae:17139.95117
# [538]	validation_0-mae:17137.95508
# [539]	validation_0-mae:17133.74609
# [540]	validation_0-mae:17132.78516
# [541]	validation_0-mae:17127.39062
# [542]	validation_0-mae:17126.22070
# [543]	validation_0-mae:17122.49219
# [544]	validation_0-mae:17119.62695
# [545]	validation_0-mae:17116.34961
# [546]	validation_0-mae:17111.12109
# [547]	validation_0-mae:17110.21094
# [548]	validation_0-mae:17107.62500
# [549]	validation_0-mae:17105.79688
# [550]	validation_0-mae:17103.14648
# [551]	validation_0-mae:17098.08203
# [552]	validation_0-mae:17096.78320
# [553]	validation_0-mae:17095.02344
# [554]	validation_0-mae:17093.74219
# [555]	validation_0-mae:17090.23633
# [556]	validation_0-mae:17086.39648
# [557]	validation_0-mae:17083.52344
# [558]	validation_0-mae:17082.81250
# [559]	validation_0-mae:17081.04492
# [560]	validation_0-mae:17078.94727
# [561]	validation_0-mae:17076.85938
# [562]	validation_0-mae:17073.97461
# [563]	validation_0-mae:17071.00391
# [564]	validation_0-mae:17068.20117
# [565]	validation_0-mae:17067.85742
# [566]	validation_0-mae:17065.64453
# [567]	validation_0-mae:17063.09961
# [568]	validation_0-mae:17060.40234
# [569]	validation_0-mae:17057.19922
# [570]	validation_0-mae:17055.25781
# [571]	validation_0-mae:17051.95117
# [572]	validation_0-mae:17051.11914
# [573]	validation_0-mae:17050.88672
# [574]	validation_0-mae:17048.27344
# [575]	validation_0-mae:17044.04883
# [576]	validation_0-mae:17039.41797
# [577]	validation_0-mae:17036.71484
# [578]	validation_0-mae:17032.24023
# [579]	validation_0-mae:17031.55859
# [580]	validation_0-mae:17028.85547
# [581]	validation_0-mae:17024.89453
# [582]	validation_0-mae:17023.19922
# [583]	validation_0-mae:17022.20508
# [584]	validation_0-mae:17021.19531
# [585]	validation_0-mae:17020.00781
# [586]	validation_0-mae:17019.01367
# [587]	validation_0-mae:17016.30469
# [588]	validation_0-mae:17016.60547
# [589]	validation_0-mae:17014.22070
# [590]	validation_0-mae:17014.18555
# [591]	validation_0-mae:17009.91602
# [592]	validation_0-mae:17008.72070
# [593]	validation_0-mae:17007.01562
# [594]	validation_0-mae:17007.01367
# [595]	validation_0-mae:17002.54688
# [596]	validation_0-mae:17001.66211
# [597]	validation_0-mae:16999.89062
# [598]	validation_0-mae:16998.94336
# [599]	validation_0-mae:16999.79492
# [600]	validation_0-mae:16999.68555
# [601]	validation_0-mae:16998.71484
# [602]	validation_0-mae:16998.31445
# [603]	validation_0-mae:16995.45898
# [604]	validation_0-mae:16993.18359
# [605]	validation_0-mae:16992.29883
# [606]	validation_0-mae:16991.68750
# [607]	validation_0-mae:16990.70703
# [608]	validation_0-mae:16990.41797
# [609]	validation_0-mae:16987.18750
# [610]	validation_0-mae:16986.09180
# [611]	validation_0-mae:16985.82617
# [612]	validation_0-mae:16987.49219
# [613]	validation_0-mae:16985.31250
# [614]	validation_0-mae:16984.57227
# [615]	validation_0-mae:16983.89453
# [616]	validation_0-mae:16982.10352
# [617]	validation_0-mae:16980.95117
# [618]	validation_0-mae:16979.24023
# [619]	validation_0-mae:16976.34375
# [620]	validation_0-mae:16976.15820
# [621]	validation_0-mae:16973.51758
# [622]	validation_0-mae:16971.93750
# [623]	validation_0-mae:16971.29883
# [624]	validation_0-mae:16969.11719
# [625]	validation_0-mae:16968.48047
# [626]	validation_0-mae:16967.55859
# [627]	validation_0-mae:16964.94531
# [628]	validation_0-mae:16964.55469
# [629]	validation_0-mae:16962.39844
# [630]	validation_0-mae:16960.42773
# [631]	validation_0-mae:16958.93555
# [632]	validation_0-mae:16958.98633
# [633]	validation_0-mae:16958.02148
# [634]	validation_0-mae:16958.00781
# [635]	validation_0-mae:16956.12891
# [636]	validation_0-mae:16954.42773
# [637]	validation_0-mae:16951.94141
# [638]	validation_0-mae:16949.51758
# [639]	validation_0-mae:16949.17383
# [640]	validation_0-mae:16947.76367
# [641]	validation_0-mae:16946.59375
# [642]	validation_0-mae:16946.32422
# [643]	validation_0-mae:16945.07031
# [644]	validation_0-mae:16944.00586
# [645]	validation_0-mae:16942.86523
# [646]	validation_0-mae:16941.26367
# [647]	validation_0-mae:16940.20508
# [648]	validation_0-mae:16937.58008
# [649]	validation_0-mae:16935.21875
# [650]	validation_0-mae:16934.43164
# [651]	validation_0-mae:16934.17383
# [652]	validation_0-mae:16932.32617
# [653]	validation_0-mae:16930.75781
# [654]	validation_0-mae:16929.88086
# [655]	validation_0-mae:16928.23242
# [656]	validation_0-mae:16924.10547
# [657]	validation_0-mae:16923.85352
# [658]	validation_0-mae:16919.76758
# [659]	validation_0-mae:16917.59961
# [660]	validation_0-mae:16917.45508
# [661]	validation_0-mae:16915.06445
# [662]	validation_0-mae:16914.23438
# [663]	validation_0-mae:16911.70898
# [664]	validation_0-mae:16906.97656
# [665]	validation_0-mae:16906.16406
# [666]	validation_0-mae:16903.93164
# [667]	validation_0-mae:16903.81641
# [668]	validation_0-mae:16900.29883
# [669]	validation_0-mae:16899.51172
# [670]	validation_0-mae:16899.66797
# [671]	validation_0-mae:16896.44141
# [672]	validation_0-mae:16895.90820
# [673]	validation_0-mae:16892.76172
# [674]	validation_0-mae:16891.66211
# [675]	validation_0-mae:16891.35938
# [676]	validation_0-mae:16890.42383
# [677]	validation_0-mae:16890.58984
# [678]	validation_0-mae:16887.65820
# [679]	validation_0-mae:16887.23047
# [680]	validation_0-mae:16887.06836
# [681]	validation_0-mae:16886.74805
# [682]	validation_0-mae:16886.83203
# [683]	validation_0-mae:16886.17188
# [684]	validation_0-mae:16883.71289
# [685]	validation_0-mae:16882.44141
# [686]	validation_0-mae:16882.72656
# [687]	validation_0-mae:16883.10352
# [688]	validation_0-mae:16882.43555
# [689]	validation_0-mae:16883.12109
# [690]	validation_0-mae:16881.96484
# [691]	validation_0-mae:16881.82227
# [692]	validation_0-mae:16881.05078
# [693]	validation_0-mae:16881.24023
# [694]	validation_0-mae:16880.47656
# [695]	validation_0-mae:16878.10352
# [696]	validation_0-mae:16877.64648
# [697]	validation_0-mae:16877.95117
# [698]	validation_0-mae:16878.00586
# [699]	validation_0-mae:16877.03516
# [700]	validation_0-mae:16877.32422
# [380]	validation_0-mae:19903.86133
# [381]	validation_0-mae:19878.68750
# [382]	validation_0-mae:19852.91211
# [383]	validation_0-mae:19829.45117
# [384]	validation_0-mae:19804.33008
# [385]	validation_0-mae:19779.72656
# [386]	validation_0-mae:19761.29883
# [387]	validation_0-mae:19738.50977
# [388]	validation_0-mae:19712.20117
# [389]	validation_0-mae:19693.20117
# [390]	validation_0-mae:19671.91406
# [391]	validation_0-mae:19650.05469
# [392]	validation_0-mae:19633.36719
# [393]	validation_0-mae:19609.74219
# [394]	validation_0-mae:19589.32227
# [395]	validation_0-mae:19569.29688
# [396]	validation_0-mae:19547.37695
# [397]	validation_0-mae:19527.87109
# [398]	validation_0-mae:19508.66406
# [399]	validation_0-mae:19492.69922
# [400]	validation_0-mae:19473.72656
# [401]	validation_0-mae:19451.45117
# [402]	validation_0-mae:19435.07422
# [403]	validation_0-mae:19415.79102
# [404]	validation_0-mae:19397.55859
# [405]	validation_0-mae:19380.62695
# [406]	validation_0-mae:19366.63477
# [407]	validation_0-mae:19352.46484
# [408]	validation_0-mae:19334.97461
# [409]	validation_0-mae:19321.82617
# [410]	validation_0-mae:19304.87500
# [411]	validation_0-mae:19289.31836
# [412]	validation_0-mae:19277.98438
# [413]	validation_0-mae:19264.33203
# [414]	validation_0-mae:19252.75391
# [415]	validation_0-mae:19244.35156
# [416]	validation_0-mae:19234.25781
# [417]	validation_0-mae:19218.99023
# [418]	validation_0-mae:19203.68555
# [419]	validation_0-mae:19192.35352
# [420]	validation_0-mae:19179.00781
# [421]	validation_0-mae:19170.68359
# [422]	validation_0-mae:19159.12305
# [423]	validation_0-mae:19148.45117
# [424]	validation_0-mae:19137.81445
# [425]	validation_0-mae:19127.31250
# [426]	validation_0-mae:19116.80469
# [427]	validation_0-mae:19107.41797
# [428]	validation_0-mae:19094.83984
# [429]	validation_0-mae:19082.78516
# [430]	validation_0-mae:19071.98633
# [431]	validation_0-mae:19060.51367
# [432]	validation_0-mae:19050.49805
# [433]	validation_0-mae:19038.53516
# [434]	validation_0-mae:19027.89062
# [435]	validation_0-mae:19015.03125
# [436]	validation_0-mae:19007.13672
# [437]	validation_0-mae:18994.27734
# [438]	validation_0-mae:18984.06250
# [439]	validation_0-mae:18972.61328
# [440]	validation_0-mae:18963.26758
# [441]	validation_0-mae:18953.05859
# [442]	validation_0-mae:18944.45117
# [443]	validation_0-mae:18933.59180
# [444]	validation_0-mae:18924.55664
# [445]	validation_0-mae:18915.52148
# [446]	validation_0-mae:18905.91016
# [447]	validation_0-mae:18895.75000
# [448]	validation_0-mae:18886.55078
# [449]	validation_0-mae:18877.85938
# [450]	validation_0-mae:18871.04492
# [451]	validation_0-mae:18865.59961
# [452]	validation_0-mae:18855.07422
# [453]	validation_0-mae:18849.34180
# [454]	validation_0-mae:18840.95508
# [455]	validation_0-mae:18832.81641
# [456]	validation_0-mae:18825.68359
# [457]	validation_0-mae:18820.28516
# [458]	validation_0-mae:18811.83789
# [459]	validation_0-mae:18804.97461
# [460]	validation_0-mae:18798.20117
# [461]	validation_0-mae:18790.92188
# [462]	validation_0-mae:18784.52344
# [463]	validation_0-mae:18778.74219
# [464]	validation_0-mae:18772.19531
# [465]	validation_0-mae:18766.53711
# [466]	validation_0-mae:18760.08203
# [467]	validation_0-mae:18754.37695
# [468]	validation_0-mae:18749.45508
# [469]	validation_0-mae:18744.00000
# [470]	validation_0-mae:18740.06445
# [471]	validation_0-mae:18734.45312
# [472]	validation_0-mae:18729.61523
# [473]	validation_0-mae:18725.11133
# [474]	validation_0-mae:18718.82812
# [475]	validation_0-mae:18715.10352
# [476]	validation_0-mae:18710.94727
# [477]	validation_0-mae:18704.76758
# [478]	validation_0-mae:18700.39648
# [479]	validation_0-mae:18694.41602
# [480]	validation_0-mae:18689.50781
# [481]	validation_0-mae:18688.04688
# [482]	validation_0-mae:18684.72852
# [483]	validation_0-mae:18679.19531
# [484]	validation_0-mae:18675.87305
# [485]	validation_0-mae:18671.35742
# [486]	validation_0-mae:18667.06250
# [487]	validation_0-mae:18662.63281
# [488]	validation_0-mae:18658.62109
# [489]	validation_0-mae:18650.49414
# [490]	validation_0-mae:18642.72656
# [491]	validation_0-mae:18638.88867
# [492]	validation_0-mae:18636.45508
# [493]	validation_0-mae:18632.65625
# [494]	validation_0-mae:18628.21484
# [495]	validation_0-mae:18625.22852
# [496]	validation_0-mae:18624.31641
# [497]	validation_0-mae:18617.15430
# [498]	validation_0-mae:18610.07617
# [499]	validation_0-mae:18606.27148
# [500]	validation_0-mae:18602.45703
# [501]	validation_0-mae:18595.48828
# [502]	validation_0-mae:18594.45117
# [503]	validation_0-mae:18587.79492
# [504]	validation_0-mae:18584.47852
# [505]	validation_0-mae:18581.26367
# [506]	validation_0-mae:18574.65430
# [507]	validation_0-mae:18575.13086
# [508]	validation_0-mae:18569.50977
# [509]	validation_0-mae:18566.29102
# [510]	validation_0-mae:18562.62305
# [511]	validation_0-mae:18557.25977
# [512]	validation_0-mae:18555.03906
# [513]	validation_0-mae:18555.45117
# [514]	validation_0-mae:18549.27344
# [515]	validation_0-mae:18546.15820
# [516]	validation_0-mae:18540.05469
# [517]	validation_0-mae:18536.82422
# [518]	validation_0-mae:18533.36328
# [519]	validation_0-mae:18534.24219
# [520]	validation_0-mae:18530.68750
# [521]	validation_0-mae:18527.63281
# [522]	validation_0-mae:18524.78125
# [523]	validation_0-mae:18521.12891
# [524]	validation_0-mae:18517.69141
# [525]	validation_0-mae:18518.50586
# [526]	validation_0-mae:18516.01367
# [527]	validation_0-mae:18512.43164
# [528]	validation_0-mae:18513.42188
# [529]	validation_0-mae:18509.90234
# [530]	validation_0-mae:18506.56836
# [531]	validation_0-mae:18505.12500
# [532]	validation_0-mae:18501.90625
# [533]	validation_0-mae:18496.64648
# [534]	validation_0-mae:18491.21875
# [535]	validation_0-mae:18488.21289
# [536]	validation_0-mae:18483.27734
# [537]	validation_0-mae:18480.15820
# [538]	validation_0-mae:18479.55078
# [539]	validation_0-mae:18474.84766
# [540]	validation_0-mae:18472.18164
# [541]	validation_0-mae:18469.65430
# [542]	validation_0-mae:18465.22852
# [543]	validation_0-mae:18462.38867
# [544]	validation_0-mae:18459.92188
# [545]	validation_0-mae:18459.18945
# [546]	validation_0-mae:18453.91211
# [547]	validation_0-mae:18451.99023
# [548]	validation_0-mae:18449.36328
# [549]	validation_0-mae:18444.81836
# [550]	validation_0-mae:18442.15820
# [551]	validation_0-mae:18438.88086
# [552]	validation_0-mae:18436.32422
# [553]	validation_0-mae:18433.50781
# [554]	validation_0-mae:18428.90430
# [555]	validation_0-mae:18426.39453
# [556]	validation_0-mae:18422.36914
# [557]	validation_0-mae:18420.84375
# [558]	validation_0-mae:18417.79102
# [559]	validation_0-mae:18415.11523
# [560]	validation_0-mae:18411.65625
# [561]	validation_0-mae:18408.79297
# [562]	validation_0-mae:18407.79883
# [563]	validation_0-mae:18403.54492
# [564]	validation_0-mae:18400.65039
# [565]	validation_0-mae:18400.24219
# [566]	validation_0-mae:18398.44922
# [567]	validation_0-mae:18396.61523
# [568]	validation_0-mae:18395.02539
# [569]	validation_0-mae:18394.72852
# [570]	validation_0-mae:18391.69922
# [571]	validation_0-mae:18387.64062
# [572]	validation_0-mae:18388.41016
# [573]	validation_0-mae:18383.64648
# [574]	validation_0-mae:18383.53320
# [575]	validation_0-mae:18382.11133
# [576]	validation_0-mae:18381.62305
# [577]	validation_0-mae:18380.58984
# [578]	validation_0-mae:18379.02734
# [579]	validation_0-mae:18375.02344
# [580]	validation_0-mae:18374.76367
# [581]	validation_0-mae:18375.80859
# [582]	validation_0-mae:18374.33789
# [583]	validation_0-mae:18372.66602
# [584]	validation_0-mae:18372.25977
# [585]	validation_0-mae:18366.59375
# [586]	validation_0-mae:18367.32812
# [587]	validation_0-mae:18364.88281
# [588]	validation_0-mae:18364.20312
# [589]	validation_0-mae:18360.39648
# [590]	validation_0-mae:18361.25977
# [591]	validation_0-mae:18360.45898
# [592]	validation_0-mae:18358.81445
# [593]	validation_0-mae:18359.98828
# [594]	validation_0-mae:18360.00000
# [595]	validation_0-mae:18355.25977
# [596]	validation_0-mae:18356.48633
# [597]	validation_0-mae:18356.13672
# [598]	validation_0-mae:18357.43945
# [599]	validation_0-mae:18357.34570
# [600]	validation_0-mae:18357.43750
# [601]	validation_0-mae:18359.08789
# [602]	validation_0-mae:18358.30078
# [603]	validation_0-mae:18354.52734
# [604]	validation_0-mae:18350.10156
# [605]	validation_0-mae:18348.81250
# [606]	validation_0-mae:18348.85547
# [607]	validation_0-mae:18344.49609
# [608]	validation_0-mae:18344.00391
# [609]	validation_0-mae:18343.38281
# [610]	validation_0-mae:18342.55469
# [611]	validation_0-mae:18338.69922
# [612]	validation_0-mae:18338.43164
# [613]	validation_0-mae:18337.62695
# [614]	validation_0-mae:18337.95117
# [615]	validation_0-mae:18335.84961
# [616]	validation_0-mae:18334.90625
# [617]	validation_0-mae:18334.61328
# [618]	validation_0-mae:18335.51562
# [619]	validation_0-mae:18332.25781
# [620]	validation_0-mae:18331.98828
# [621]	validation_0-mae:18331.70117
# [622]	validation_0-mae:18331.17188
# [623]	validation_0-mae:18332.11133
# [624]	validation_0-mae:18329.82422
# [625]	validation_0-mae:18325.19336
# [626]	validation_0-mae:18325.27539
# [627]	validation_0-mae:18326.05664
# [628]	validation_0-mae:18325.50000
# [629]	validation_0-mae:18323.76758
# [630]	validation_0-mae:18323.68750
# [631]	validation_0-mae:18324.67773
# [632]	validation_0-mae:18322.83984
# [633]	validation_0-mae:18322.62305
# [634]	validation_0-mae:18323.84180
# [635]	validation_0-mae:18322.00586
# [636]	validation_0-mae:18320.48828
# [637]	validation_0-mae:18319.16016
# [638]	validation_0-mae:18317.49805
# [639]	validation_0-mae:18317.07227
# [640]	validation_0-mae:18318.05859
# [641]	validation_0-mae:18317.66406
# [642]	validation_0-mae:18317.07031
# [643]	validation_0-mae:18318.10352
# [644]	validation_0-mae:18316.68164
# [645]	validation_0-mae:18315.66797
# [646]	validation_0-mae:18313.44141
# [647]	validation_0-mae:18313.41602
# ...
# [523]	validation_0-mae:17789.72656
# [524]	validation_0-mae:17788.02344
# [525]	validation_0-mae:17783.15820
# [526]	validation_0-mae:17777.79492
# [527]	validation_0-mae:17772.60938
# [528]	validation_0-mae:17768.62305
# [529]	validation_0-mae:17764.71484
# [530]	validation_0-mae:17760.84570
# [531]	validation_0-mae:17757.11328
# [532]	validation_0-mae:17752.39062
# [533]	validation_0-mae:17748.54102
# [534]	validation_0-mae:17745.64648
# [535]	validation_0-mae:17741.05469
# [536]	validation_0-mae:17737.60938
# [537]	validation_0-mae:17733.11719
# [538]	validation_0-mae:17730.99609
# [539]	validation_0-mae:17729.45312
# [540]	validation_0-mae:17725.97852
# [541]	validation_0-mae:17721.13281
# [542]	validation_0-mae:17719.21875
# [543]	validation_0-mae:17716.02930
# [544]	validation_0-mae:17711.83203
# [545]	validation_0-mae:17709.98828
# [546]	validation_0-mae:17705.73242
# [547]	validation_0-mae:17701.75000
# [548]	validation_0-mae:17697.05078
# [549]	validation_0-mae:17693.98047
# [550]	validation_0-mae:17690.45508
# [551]	validation_0-mae:17687.31250
# [552]	validation_0-mae:17684.73828
# [553]	validation_0-mae:17681.24609
# [554]	validation_0-mae:17677.60938
# [555]	validation_0-mae:17674.18555
# [556]	validation_0-mae:17671.50781
# [557]	validation_0-mae:17668.34375
# [558]	validation_0-mae:17664.57617
# [559]	validation_0-mae:17660.09570
# [560]	validation_0-mae:17656.94531
# [561]	validation_0-mae:17654.93164
# [562]	validation_0-mae:17652.31445
# [563]	validation_0-mae:17648.88672
# [564]	validation_0-mae:17646.74414
# [565]	validation_0-mae:17645.11719
# [566]	validation_0-mae:17642.28711
# [567]	validation_0-mae:17638.69531
# [568]	validation_0-mae:17636.48633
# [569]	validation_0-mae:17632.34961
# [570]	validation_0-mae:17628.99414
# [571]	validation_0-mae:17625.32031
# [572]	validation_0-mae:17623.27539
# [573]	validation_0-mae:17618.90234
# [574]	validation_0-mae:17615.01758
# [575]	validation_0-mae:17612.57227
# [576]	validation_0-mae:17610.25781
# [577]	validation_0-mae:17607.39062
# [659]	validation_0-mae:17486.11719
# [660]	validation_0-mae:17485.12305
# [661]	validation_0-mae:17484.09961
# [662]	validation_0-mae:17482.10547
# [663]	validation_0-mae:17482.09180
# [664]	validation_0-mae:17480.46875
# [665]	validation_0-mae:17482.17578
# [666]	validation_0-mae:17481.05859
# [667]	validation_0-mae:17481.16602
# [668]	validation_0-mae:17479.04688
# [669]	validation_0-mae:17478.70508
# [670]	validation_0-mae:17478.81250
# [671]	validation_0-mae:17476.71484
# [672]	validation_0-mae:17476.92773
# [673]	validation_0-mae:17475.24609
# [674]	validation_0-mae:17474.32617
# [675]	validation_0-mae:17472.54102
# [676]	validation_0-mae:17472.75586
# [677]	validation_0-mae:17471.17969
# [678]	validation_0-mae:17471.35938
# [679]	validation_0-mae:17471.48633
# [680]	validation_0-mae:17471.80273
# [681]	validation_0-mae:17470.15234
# [682]	validation_0-mae:17469.10352
# [683]	validation_0-mae:17466.88086
# [684]	validation_0-mae:17465.38086
# [685]	validation_0-mae:17466.71875
# [686]	validation_0-mae:17465.30859
# [687]	validation_0-mae:17465.23047
# [688]	validation_0-mae:17464.27930
# [689]	validation_0-mae:17460.76758
# [690]	validation_0-mae:17459.90820
# [691]	validation_0-mae:17457.89258
# [692]	validation_0-mae:17458.61328
# [693]	validation_0-mae:17458.13867
# [694]	validation_0-mae:17458.07617
# [695]	validation_0-mae:17458.53516
# [696]	validation_0-mae:17458.83789
# [697]	validation_0-mae:17458.08594
# [698]	validation_0-mae:17457.33594
# [699]	validation_0-mae:17455.96484
# [700]	validation_0-mae:17455.32422
# [701]	validation_0-mae:17452.56250
# [702]	validation_0-mae:17451.46289
# [703]	validation_0-mae:17451.49805
# [704]	validation_0-mae:17450.83789
# [705]	validation_0-mae:17449.15625
# [706]	validation_0-mae:17449.19727
# [707]	validation_0-mae:17448.45703
# [708]	validation_0-mae:17446.48633
# [709]	validation_0-mae:17443.98633
# [710]	validation_0-mae:17444.33398
# [711]	validation_0-mae:17441.63086
# [712]	validation_0-mae:17442.33203
# [713]	validation_0-mae:17441.50391
# [714]	validation_0-mae:17438.28320
# [715]	validation_0-mae:17437.45898
# [716]	validation_0-mae:17437.33984
# [717]	validation_0-mae:17437.33203
# [718]	validation_0-mae:17437.48438
# [719]	validation_0-mae:17436.46484
# [720]	validation_0-mae:17435.68750
# [721]	validation_0-mae:17436.04883
# [722]	validation_0-mae:17435.24805
# [723]	validation_0-mae:17435.79688
# [724]	validation_0-mae:17436.15430
# [725]	validation_0-mae:17435.68750
# [726]	validation_0-mae:17434.68750
# [727]	validation_0-mae:17435.23828
# [728]	validation_0-mae:17433.90430
# [729]	validation_0-mae:17431.65625
# [730]	validation_0-mae:17430.66602
# [731]	validation_0-mae:17429.90820
# [732]	validation_0-mae:17428.20117
# [733]	validation_0-mae:17425.97266
# [734]	validation_0-mae:17425.98242
# [735]	validation_0-mae:17423.09375
# [736]	validation_0-mae:17423.14062
# [737]	validation_0-mae:17421.52148
# [738]	validation_0-mae:17422.07617
# [739]	validation_0-mae:17419.89648
# [740]	validation_0-mae:17418.55469
# [741]	validation_0-mae:17417.33984
# [742]	validation_0-mae:17415.15820
# [743]	validation_0-mae:17414.07031
# [744]	validation_0-mae:17411.24219
# [745]	validation_0-mae:17411.47656
# [746]	validation_0-mae:17410.95117
# [747]	validation_0-mae:17410.54102
# [748]	validation_0-mae:17408.69141
# [749]	validation_0-mae:17409.05469
# [750]	validation_0-mae:17406.41992
# [751]	validation_0-mae:17404.70312
# [752]	validation_0-mae:17403.83594
# [753]	validation_0-mae:17402.05859
# [754]	validation_0-mae:17401.63281
# [755]	validation_0-mae:17399.81445
# [756]	validation_0-mae:17397.79688
# [757]	validation_0-mae:17395.36914
# [758]	validation_0-mae:17394.85547
# [759]	validation_0-mae:17393.12305
# [760]	validation_0-mae:17391.66992
# [761]	validation_0-mae:17389.65430
# [762]	validation_0-mae:17390.17773
# [763]	validation_0-mae:17387.95117
# [764]	validation_0-mae:17386.93945
# [765]	validation_0-mae:17384.49609
# [766]	validation_0-mae:17383.34961
# [767]	validation_0-mae:17382.99219
# [768]	validation_0-mae:17381.29688
# [769]	validation_0-mae:17379.83594
# [770]	validation_0-mae:17379.48438
# [771]	validation_0-mae:17378.19922
# [772]	validation_0-mae:17377.94336
# [773]	validation_0-mae:17378.30859
# [774]	validation_0-mae:17376.86719
# [775]	validation_0-mae:17377.03516
# [776]	validation_0-mae:17376.57227
# [777]	validation_0-mae:17374.90430
# [778]	validation_0-mae:17373.14648
# [779]	validation_0-mae:17373.00586
# [780]	validation_0-mae:17373.54102
# [781]	validation_0-mae:17373.29688
# [782]	validation_0-mae:17372.04883
# [783]	validation_0-mae:17372.55469
# [784]	validation_0-mae:17371.39648
# [785]	validation_0-mae:17369.99805
# [786]	validation_0-mae:17368.78516
# [787]	validation_0-mae:17368.67969
# [788]	validation_0-mae:17367.76953
# [789]	validation_0-mae:17367.08008
# [790]	validation_0-mae:17366.46484
# [791]	validation_0-mae:17365.01953
# [792]	validation_0-mae:17364.49023
# [793]	validation_0-mae:17362.99219
# [794]	validation_0-mae:17362.44531
# [795]	validation_0-mae:17362.62305
# [796]	validation_0-mae:17361.58398
# [797]	validation_0-mae:17360.70312
# [798]	validation_0-mae:17359.69141
# [799]	validation_0-mae:17358.79688
# [800]	validation_0-mae:17356.96875
# [801]	validation_0-mae:17354.77344
# [802]	validation_0-mae:17353.91016
# [803]	validation_0-mae:17353.16406
# [804]	validation_0-mae:17351.94922
# [805]	validation_0-mae:17351.99023
# [806]	validation_0-mae:17349.58203
# [807]	validation_0-mae:17348.60352
# [808]	validation_0-mae:17346.18555
# [809]	validation_0-mae:17345.51758
# [810]	validation_0-mae:17344.85938
# [811]	validation_0-mae:17343.70508
# [812]	validation_0-mae:17343.55859
# [813]	validation_0-mae:17342.42383
# [814]	validation_0-mae:17341.81250
# [815]	validation_0-mae:17342.16992
# [816]	validation_0-mae:17342.04492
# [817]	validation_0-mae:17340.83984
# [818]	validation_0-mae:17341.26562
# [819]	validation_0-mae:17340.01953
# [820]	validation_0-mae:17339.31250
# [821]	validation_0-mae:17339.23438
# [822]	validation_0-mae:17338.39258
# [823]	validation_0-mae:17338.20703
# [824]	validation_0-mae:17335.98633
# [825]	validation_0-mae:17334.88672
# [826]	validation_0-mae:17335.79492
# [827]	validation_0-mae:17334.86328
# [828]	validation_0-mae:17334.04102
# [829]	validation_0-mae:17333.30273
# [830]	validation_0-mae:17333.81641
# [831]	validation_0-mae:17333.10156
# [832]	validation_0-mae:17332.91016
# [833]	validation_0-mae:17331.88672
# [834]	validation_0-mae:17330.79883
# [835]	validation_0-mae:17330.11914
# [836]	validation_0-mae:17329.67188
# [837]	validation_0-mae:17329.50391
# [838]	validation_0-mae:17329.03320
# [839]	validation_0-mae:17328.13477
# [840]	validation_0-mae:17327.96484
# [841]	validation_0-mae:17326.77930
# [842]	validation_0-mae:17326.30859
# [843]	validation_0-mae:17326.14258
# [844]	validation_0-mae:17324.57031
# [845]	validation_0-mae:17325.07617
# [846]	validation_0-mae:17323.29102
# [847]	validation_0-mae:17322.29297
# [848]	validation_0-mae:17321.89258
# [849]	validation_0-mae:17321.11719
# [850]	validation_0-mae:17318.84180
# [851]	validation_0-mae:17318.95312
# [852]	validation_0-mae:17317.78711
# [853]	validation_0-mae:17317.74023
# [854]	validation_0-mae:17317.06445
# [855]	validation_0-mae:17317.01758
# [856]	validation_0-mae:17316.29102
# [857]	validation_0-mae:17315.61719
# [858]	validation_0-mae:17314.54297
# [859]	validation_0-mae:17314.13086
# [860]	validation_0-mae:17313.00195
# [861]	validation_0-mae:17311.82422
# [862]	validation_0-mae:17311.15234
# [863]	validation_0-mae:17309.71094
# [864]	validation_0-mae:17309.82031
# [865]	validation_0-mae:17308.18555
# [866]	validation_0-mae:17307.13672
# [867]	validation_0-mae:17306.77148
# [868]	validation_0-mae:17304.87305
# [869]	validation_0-mae:17305.69141
# [870]	validation_0-mae:17304.29883
# [871]	validation_0-mae:17304.25391
# [872]	validation_0-mae:17302.53516
# [873]	validation_0-mae:17302.18750
# [874]	validation_0-mae:17300.32227
# [875]	validation_0-mae:17300.56641
# [876]	validation_0-mae:17300.52539
# [877]	validation_0-mae:17300.99023
# [878]	validation_0-mae:17299.53516
# [879]	validation_0-mae:17299.49219
# [880]	validation_0-mae:17300.21680
# [881]	validation_0-mae:17299.91211
# [882]	validation_0-mae:17298.33398
# [883]	validation_0-mae:17298.06250
# [884]	validation_0-mae:17296.24609
# [885]	validation_0-mae:17295.96289
# [886]	validation_0-mae:17295.93945
# [887]	validation_0-mae:17295.76562
# [888]	validation_0-mae:17295.74023
# [889]	validation_0-mae:17295.34766
# [890]	validation_0-mae:17294.06836
# [891]	validation_0-mae:17293.89844
# [892]	validation_0-mae:17294.04688
# [893]	validation_0-mae:17292.99805
# [894]	validation_0-mae:17292.97656
# [895]	validation_0-mae:17291.43750
# [896]	validation_0-mae:17291.47656
# [897]	validation_0-mae:17290.57617
# [898]	validation_0-mae:17290.79688
# [899]	validation_0-mae:17289.76562
# [900]	validation_0-mae:17289.50000
# [901]	validation_0-mae:17289.83984
# [902]	validation_0-mae:17289.75781
# [903]	validation_0-mae:17288.13477
# [904]	validation_0-mae:17288.09180
# [905]	validation_0-mae:17288.08008
# [906]	validation_0-mae:17286.21289
# [907]	validation_0-mae:17286.10352
# [908]	validation_0-mae:17285.81445
# [909]	validation_0-mae:17285.29492
# [910]	validation_0-mae:17285.91797
# [911]	validation_0-mae:17285.84570
# [912]	validation_0-mae:17285.79688
# [913]	validation_0-mae:17286.41406
# [914]	validation_0-mae:17284.50391
# [915]	validation_0-mae:17284.40039
# [916]	validation_0-mae:17284.13867
# [917]	validation_0-mae:17283.51758
# [918]	validation_0-mae:17283.55078
# [919]	validation_0-mae:17284.16016
# [920]	validation_0-mae:17283.00977
# [921]	validation_0-mae:17281.44141
# [922]	validation_0-mae:17280.81445
# [923]	validation_0-mae:17280.90625
# [924]	validation_0-mae:17280.77148
# [925]	validation_0-mae:17279.85352
# [926]	validation_0-mae:17277.66406
# [927]	validation_0-mae:17278.08984
# [928]	validation_0-mae:17277.47070
# [929]	validation_0-mae:17275.76172
# [930]	validation_0-mae:17276.12305
# [931]	validation_0-mae:17275.41406
# [932]	validation_0-mae:17275.24609
# [933]	validation_0-mae:17275.16602
# [934]	validation_0-mae:17274.87109
# [935]	validation_0-mae:17275.23828
# [936]	validation_0-mae:17274.52930
# [937]	validation_0-mae:17274.36914
# [938]	validation_0-mae:17274.48242
# [939]	validation_0-mae:17274.91016
# [940]	validation_0-mae:17273.50000
# [941]	validation_0-mae:17271.83984
# [942]	validation_0-mae:17271.90820
# [943]	validation_0-mae:17271.38672
# [944]	validation_0-mae:17270.49609
# [945]	validation_0-mae:17269.51172
# [946]	validation_0-mae:17269.28125
# [947]	validation_0-mae:17269.64062
# [948]	validation_0-mae:17268.97852
# [949]	validation_0-mae:17268.82031
# [950]	validation_0-mae:17268.67383
# [951]	validation_0-mae:17268.19922
# [952]	validation_0-mae:17268.27344
# [953]	validation_0-mae:17267.57422
# [954]	validation_0-mae:17266.77344
# [955]	validation_0-mae:17266.16016
# [956]	validation_0-mae:17266.63477
# [957]	validation_0-mae:17264.64062
# [958]	validation_0-mae:17264.67188
# [959]	validation_0-mae:17264.60156
# [960]	validation_0-mae:17264.61133
# [961]	validation_0-mae:17264.13281
# [962]	validation_0-mae:17263.99219
# [963]	validation_0-mae:17264.23242
# [964]	validation_0-mae:17264.65430
# [965]	validation_0-mae:17264.95117
# [966]	validation_0-mae:17265.30664
# [967]	validation_0-mae:17264.11719
# [968]	validation_0-mae:17264.03711
# [969]	validation_0-mae:17264.30078
# [970]	validation_0-mae:17263.02148
# [971]	validation_0-mae:17263.63281
# [972]	validation_0-mae:17264.54688
# [973]	validation_0-mae:17263.37305
# [974]	validation_0-mae:17263.60938
# [975]	validation_0-mae:17264.00781
# [976]	validation_0-mae:17265.39648
# [977]	validation_0-mae:17265.83594
# [978]	validation_0-mae:17265.15820
# 16362.271127724245

# %% [markdown]
# # XGBoost with Early Stopping Params
# * Test 2 combinations:
# 1. random_state=0, n_estimators=1500, learning_rate=0.01 and early_stopping_rounds set to 20 (may be overfitting)
# 2. random_state=0, n_estimators=175 n_estimators=300, n_estimators=500, learning_rate=0.05 (may be underfitting)

# %%
# try out the optimal xgboost
xbg_model_1 = xgb.XGBRegressor(n_estimators=900, learning_rate=0.01, random_state=0)
# create the pipeline for the final model
xgb_pipeline_1 = Pipeline(steps = [
    ('preprocess', preprocessor_1),
    ('model', xbg_model_1)
])
xgb_pipeline_1.fit(X_clean, y)

xgb_pred_1 = xgb_pipeline_1.predict(X_test_clean)

# %%
output = pd.DataFrame({'Id': X_test_clean.index,
                       'SalePrice': xgb_pred_1})
output.to_csv('xgb_submission.csv', index=False)

# %%
# more xgb models with a lower n estimators
# xgb_model_6 = xgb.XGBRegressor(n_estimators=10, random_state=0)
# xgb_model_7 = xgb.XGBRegressor(n_estimators=25, random_state=0)
# xgb_model_8 = xgb.XGBRegressor(n_estimators=35, random_state=0)
# xgb_model_9 = xgb.XGBRegressor(n_estimators=55, random_state=0)
# xgb_model_10 = xgb.XGBRegressor(n_estimators=75, random_state=0)
# xgb_model_11 = xgb.XGBRegressor(n_estimators=20, random_state=0)
# xgb_model_12 = xgb.XGBRegressor(n_estimators=15, random_state=0)

# xgb_list_2 = [xgb_model_6, xgb_model_7, xgb_model_8, xgb_model_9, xgb_model_10, xgb_model_11, xgb_model_12]
# xgb_accuracy_2 = []
# for model in xgb_list_2:
#     xgb_accuracy_2.append(test_model(model, preprocessor_1))

# %%
# num_estimator_vals = [10, 25, 35, 55, 75, 20, 15]
# ax_7 = sns.lineplot(x=num_estimator_vals, y=xgb_accuracy_2)
# ax_7.set_title('XGB Accuracy vs Number of Estimator Values')
# ax_7.set_xlabel('Number of Estimator Values')
# ax_7.set_ylabel('House Price Prediction Error ($)')

# %%
# change the learning rate to increase model accuracy
# xgb_model_13 = xgb.XGBRegressor(n_estimators=20, learning_rate=0.2, random_state=0)
# xgb_model_14 = xgb.XGBRegressor(n_estimators=20, learning_rate=0.1, random_state=0)
# xgb_model_15 = xgb.XGBRegressor(n_estimators=20, learning_rate=0.05, random_state=0)
# xgb_model_16 = xgb.XGBRegressor(n_estimators=20, learning_rate=0.01, random_state=0)
# xgb_model_17 = xgb.XGBRegressor(n_estimators=20, learning_rate=0.008, random_state=0)

# xgb_list_4 = [xgb_model_13, xgb_model_14, xgb_model_15, xgb_model_16, xgb_model_17]
# xgb_accuracy_4 = []
# for model in xgb_list_4:
#     xgb_accuracy_4.append(test_model(model, preprocessor_1))

# %%
# learn_rate_vals = [0.2, 0.1, 0.05, 0.01, 0.008]
# ax_8 = sns.lineplot(x=learn_rate_vals, y=xgb_accuracy_4)
# ax_8.set_title('XGB Accuracy vs Number of Estimator Values')
# ax_8.set_xlabel('Learning Rate')
# ax_8.set_ylabel('House Price Prediction Error ($)')

# %%
# change the learning rate to increase model accuracy again
# xgb_model_13 = xgb.XGBRegressor(n_estimators=35, learning_rate=0.05, random_state=0)
# print(test_model(xgb_model_13, preprocessor_1))
